# %%
from sklearn.datasets import make_blobs
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Generate linearly separable data
X, y = make_blobs(n_samples=500, centers=2, n_features=2, cluster_std=1.0, random_state=42)

# Convert to DataFrame
df = pd.DataFrame(X, columns=['X1', 'X2'])
df['y'] = y  # Add target column

# Preview
print(df.head())

# Visualize
sns.scatterplot(x='X1', y='X2', hue='y', data=df)
plt.title('Linearly Separable Blob Dataset')
plt.show()
# Out:
#          X1         X2  y
# 0 -2.988372   8.828627  0
# 1 -4.024389  10.381160  0
# 2 -3.483879   9.801371  0
# 3 -2.637115   8.058746  0
# 4  3.690480   4.605552  1

# %%
import pandas as pd

# %%
df.head()
# Out:
#          X1         X2  y
# 0 -2.988372   8.828627  0
# 1 -4.024389  10.381160  0
# 2 -3.483879   9.801371  0
# 3 -2.637115   8.058746  0
# 4  3.690480   4.605552  1

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,2]

# %%
from sklearn.linear_model import Perceptron

# %%
p = Perceptron(max_iter=100, eta0=0.1, random_state=0)

# %%
p.fit(X,y)
# Out:
# Perceptron(eta0=0.1, max_iter=100)

# %%
p.coef_
# Out:
# array([[ 0.93617168, -0.47917235]])

# %%
p.intercept_
# Out:
# array([0.1])

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X.values, y.values, clf=p)
plt.title('Perceptron')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
